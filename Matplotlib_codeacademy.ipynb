# %% [markdown]
# <a href="https://colab.research.google.com/github/sojungkang/colab_example/blob/master/Matplotlib_codeacademy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Basic line plot
# - plt.plot(x_values, y_values) will create the line graph

# %%
from matplotlib import pyplot as plt
# Days of the week:
days = [0, 1, 2, 3, 4, 5, 6]
# Your Money:
money_spent = [10, 12, 12, 10, 14, 22, 24]
# Your Friend's Money:
money_spent_2 = [11, 14, 15, 15, 22, 21, 12]
# Plot your money:
plt.plot(days, money_spent)
# Plot your friend's money:
plt.plot(days, money_spent_2)

##color of the lines
plt.plot(days, money_spent, color='green')
plt.plot(days, money_spent_2, color='red')

##Line style
# Dashed:
# plt.plot(x_values, y_values, linestyle='--')
# # Dotted:
# plt.plot(x_values, y_values, linestyle=':')
# # No line:
# plt.plot(x_values, y_values, linestyle='')

##Keyword marker
# # A circle:
# plt.plot(x_values, y_values, marker='o')
# # A square:
# plt.plot(x_values, y_values, marker='s')
# # A star:
# plt.plot(days, money_spent, marker='*')


# Display the result:
plt.show()

# %% [markdown]
# **Axis and Labels**

# %%
from matplotlib import pyplot as plt

x = range(12)
y = [3000, 3005, 3010, 2900, 2950, 3050, 3000, 3100, 2980, 2980, 2920, 3010]
plt.plot(x, y)

#your code here
##x-axis goes from 0 to 12, and the y-axis goes from 2900 to 3100.
plt.axis([0, 12, 2900, 3100])

##labeling 
plt.xlabel('Time')
plt.ylabel('Dollars spent on coffee')
plt.title('My Last Twelve Years of Coffee')
plt.show()

# %% [markdown]
# **Subplots**
# - The command plt.subplot() needs three arguments to be passed into it:
#     - The number of rows of subplots
#     - The number of columns of subplots
#     - The index of the subplot we want to create

# %%
# Data sets
x = [1, 2, 3, 4]
y = [1, 2, 3, 4]

# First Subplot
plt.subplot(1, 2, 1)
plt.plot(x, y, color='green')
plt.title('First Subplot')

# Second Subplot
plt.subplot(1, 2, 2)
plt.plot(x, y, color='steelblue')
plt.title('Second Subplot')

# Display both subplots
plt.show()

# %%
from matplotlib import pyplot as plt

months = range(12)
temperature = [36, 36, 39, 52, 61, 72, 77, 75, 68, 57, 48, 48]
flights_to_hawaii = [1200, 1300, 1100, 1450, 850, 750, 400, 450, 400, 860, 990, 1000]

plt.subplot(1,2,2)
plt.plot(flights_to_hawaii, temperature, marker='o')
plt.show()

# %% [markdown]
# **customize the spacing between subplots**
#  - use the plt.subplots_adjust() command
#      - keyword arguments that can move your plots within the figure:
#
#      - left -> the left-side margin, with a default of 0.125. increase this number to make room for a y-axis label
#      - right —> the right-side margin, with a default of 0.9. increase this to make more room for the figure, or decrease it to make room for a legend
#      - bottom —> the bottom margin, with a default of 0.1. increase this to make room for tick mark labels or an x-axis label
#      - top —> the top margin, with a default of 0.9
#      - wspace —> the horizontal space between adjacent subplots, with a default of 0.2
#      - hspace —> the vertical space between adjacent subplots, with a default of 0.2

# %%
# Left Plot
plt.subplot(1, 2, 1)
plt.plot([-2, -1, 0, 1, 2], [4, 1, 0, 1, 4])

# Right Plot
plt.subplot(1, 2, 2)
plt.plot([-2, -1, 0, 1, 2], [4, 1, 0, 1, 4])

# Subplot Adjust
plt.subplots_adjust(wspace=0.35)

plt.show()

# %%
from matplotlib import pyplot as plt

x = range(7)
straight_line = [0, 1, 2, 3, 4, 5, 6]
parabola = [0, 1, 4, 9, 16, 25, 36]
cubic = [0, 1, 8, 27, 64, 125, 216]

plt.subplot(2, 1, 1)
plt.plot(straight_line, x)

plt.subplot(2, 2, 3)
plt.plot(x, parabola)

plt.subplot(2, 2, 4)
plt.plot(x, cubic)

plt.subplots_adjust(wspace=0.35, bottom=0.2)
plt.show()

# %% [markdown]
# **legends**
# - multiple lines on a single graph we can label them by using the command plt.legend()
# - the position values loc accept: https://datascienceschool.net/view-notebook/d0b1637803754bb083b5722c9f2209d0/

# %%
from matplotlib import pyplot as plt

plt.plot([0, 1, 2, 3, 4], [0, 1, 4, 9, 16],
         label="parabola")
plt.plot([0, 1, 2, 3, 4], [0, 1, 8, 27, 64],
         label="cubic")
plt.legend() # Still need this command!
plt.show()

# %%
from matplotlib import pyplot as plt
# %matplotlib inline 

months = range(12)
hyrule = [63, 65, 68, 70, 72, 72, 73, 74, 71, 70, 68, 64]
kakariko = [52, 52, 53, 68, 73, 74, 74, 76, 71, 62, 58, 54]
gerudo = [98, 99, 99, 100, 99, 100, 98, 101, 101, 97, 98, 99]

plt.plot(months, hyrule)
plt.plot(months, kakariko)
plt.plot(months, gerudo)

#create your legend here
legend_labels = ["Hyrule", "Kakariko", "Gerudo Valley"]
plt.legend(legend_labels, loc=2)

plt.show()

# %% [markdown]
# **Modifying ticks**

# %%
from matplotlib import pyplot as plt
# %matplotlib inline 

month_names = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep","Oct", "Nov", "Dec"]

months = range(12)
conversion = [0.05, 0.08, 0.18, 0.28, 0.4, 0.66, 0.74, 0.78, 0.8, 0.81, 0.85, 0.85]

plt.xlabel("Months")
plt.ylabel("Conversion")

plt.plot(months, conversion)

ax = plt.gca() #Get Current Axes -> provides a handle to the last active axes
ax.set_xticks(months) # x축 단위 바꾸기 
ax.set_xticklabels(month_names)
ax.set_yticks([0.10, 0.25, 0.5, 0.75]) # y축 단위 바꾸기 
ax.set_yticklabels(["10%", "25%", "50%", "75%"])

plt.show()

# %% [markdown]
# **Figures**

# %%
from matplotlib import pyplot as plt

word_length = [8, 11, 12, 11, 13, 12, 9, 9, 7, 9]
power_generated = [753.9, 768.8, 780.1, 763.7, 788.5, 782, 787.2, 806.4, 806.2, 798.9]
years = [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]

plt.close('all') # clear all existing plots 

plt.plot(years, word_length) #word_length against years
plt.savefig('winning_word_lengths.png')

plt.figure(figsize=(7,3))
plt.plot(years, power_generated) #power_generated against years
plt.savefig('power_generated.png')

plt.show()

# %%
from matplotlib import pyplot as plt

fig, ax1 = plt.subplots()
ax2 = ax1.twinx() # Create a twin Axes sharing the x-axis

x = [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]
y1 = [5, 4.7, 4.6, 4.4, 4.3, 4.1, 4.2, 4.2, 4.2, 4.1]
y2 = [8.2, 7, 6.5, 5.3, 5.2, 4, 4.6, 4.5, 4.2, 3.7]

line1 = ax1.plot(x, y1, color='pink', marker='o')
line2 = ax2.plot(x, y2, color='gray', marker='o')

ax1.set_xlabel("Year")
ax1.set_ylabel("Divorce rate in Maine")
ax2.set_ylabel("Magarine consumed")
plt.title('Correlation between divorce rate in Maine and Magarine consumption')

#set y limit
ax1.set_ylim(3.90, 5.20)
ax2.set_ylim(2.00, 8.20)

#plot legend for all y axis
lines = line1 + line2
labels = ["divorce rate", "Margarine consumed"]

plt.legend(lines, labels, loc=0)

plt.show()
